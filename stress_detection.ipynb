# %% [markdown]
# # 1.Importing Necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # 2.Mounting Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# #3.Reading datasets

# %%
df=pd.read_csv('/content/drive/MyDrive/datasets/stess_detection_datasets/train.csv')

# %%
df.head()

# %% [markdown]
# #4.EDA Process

# %%
df.shape

# %%
df.columns

# %%
df.info()

# %%
df.describe()

# %%
df['condition'].value_counts()

# %%
sns.countplot(df['condition'])
plt.title('Stress Condition Distribution')
plt.show()

# %%
sns.histplot(df['HR'],kde=True) #Normal heart rate is 60-80 bpm
plt.title('Heart Rate Distribution')
plt.show()

# %%
sns.boxplot(x='condition',y='HF',data=df)
plt.title('Stress Level VS Heart Level')
plt.show()

# %%
sns.boxplot(x='condition', y='RMSSD', data=df) #low rmssd high stress
plt.title("RMSSD across Stress Levels")
plt.show()

# %%
plt.figure(figsize=(12,8))

corr = df.corr(numeric_only=True)

sns.heatmap(corr, cmap='coolwarm', center=0)

plt.title("Feature Correlation Heatmap")
plt.show()

# %%
# sns.pairplot(
#     df[['HR','RMSSD','SDRR','LF_HF','condition']],
#     hue='condition'
# )
# plt.show()

# %% [markdown]
# #5.Handle Missing Values

# %%
df.isnull().sum()

# %%
#removing unnecessary columns
df.drop(columns=['datasetId'],inplace=True)

# %% [markdown]
# # 6.Encode Target Label

# %%
encoder=LabelEncoder()
df['condition']=encoder.fit_transform(df['condition'])

# %% [markdown]
# # 7.Separate Features and Target

# %%
x=df.drop('condition',axis=1)
y=df['condition']

# %%
x.head()

# %%
y.value_counts()
